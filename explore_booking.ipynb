# %%
import pandas as pd
import numpy as np

# %%
PATH ='/media/sf_ubuntuShareDrive/Datasets/booking_weekly/10th_2021.csv'
df = pd.read_csv(PATH, dtype={
                           "Schd Time Start" : str,
                           "PO": str,
                           "Route number" : str})

# %%
df['Route number'] = df['Route number'].astype('str')
df[['Route number', 'weekday']] = df['Route number'].str.split(
    '-', 1, expand=True)
df['Route number']
# Out:
# 0        BR2
# 1        BR2
# 2        RLH
# 3        BIN
# 4        BIN
#         ...
# 10091    RLH
# 10092    RL4
# 10093    RL4
# 10094    BR2
# 10095    RL4
# Name: Route number, Length: 10096, dtype: object

# %%
df[df['Route number'].eq('RRR')]
# Out:
#           Job No      Date Schd Time Start Schd Time End    Latitude  \
# 662   2681796.00  16/03/21             NaN           NaN  151.174891
# 663   2681797.00  16/03/21             NaN           NaN  151.204361
# 664   2681798.00  16/03/21             NaN           NaN  150.817217
# 665   2681798.01  16/03/21             NaN           NaN  150.817217
# 666   2681799.00  16/03/21             NaN           NaN  150.771938
# ...          ...       ...             ...           ...         ...
# 8986  2674991.00  10/03/21             NaN           NaN  151.199745
# 8987  2674996.00  10/03/21             NaN           NaN  151.138844
# 9068  2675001.00  10/03/21             NaN           NaN  151.256069
# 9381  2675002.00  10/03/21             NaN           NaN  151.127308
# 9528  2675003.00  10/03/21             NaN           NaN  150.688443
#
#       Longitude  Customer number                             Customer Name  \
# 662  -33.898530          2226.02                      SMT - Cairo Takeaway
# 663  -33.893101          2377.00                       Coffee Tea & Me P/L
# 664  -33.608705          3355.00                          Academy Services
# 665  -33.608705          3355.00                          Academy Services
# 666  -33.961090          2121.00                     Shepherd's Landscapes
# ...         ...              ...                                       ...
# 8986 -33.899173          4202.00                     Dens in Dente Pty LTd
# 8987 -33.880779          4445.00                                Haba Ocean
# 9068 -33.920568          4173.00                                 Fish Bowl
# 9381 -34.028965          2654.00                    Little Learning School
# 9528 -33.764070          4033.00  Pizza Hut- CM Damania Investment Pty Ltd
#
#                   Site Name                 Address 1  ...  \
# 662                     NaN              81 Enmore Rd  ...
# 663     Coffee Tea & Me P/L        93B Redfern Street  ...
# 664                     NaN             299 George St  ...
# 665                     NaN             299 George St  ...
# 666   Shepherd's Landscapes          143 Gregory Road  ...
# ...                     ...                       ...  ...
# 8986                    NaN  shop 2/138-142 Botany Rd  ...
# 8987                    NaN         94A Ramsay Street  ...
# 9068                    NaN         254 Coogee Bay Rd  ...
# 9381                    NaN           32 Cawarra Road  ...
# 9528                    NaN         Shop 2/29 York Rd  ...
#
#      Alternate Service Ref 1 Alternate Service Ref 2 Notes  \
# 662                      NaN                     NaN   NaN
# 663                      NaN                     NaN   NaN
# 664                      NaN                     NaN   NaN
# 665                      NaN                     NaN   NaN
# 666                      NaN                     NaN   NaN
# ...                      ...                     ...   ...
# 8986                     NaN                     NaN   NaN
# 8987                     NaN                     NaN   NaN
# 9068                     NaN                     NaN   NaN
# 9381                     NaN                     NaN   NaN
# 9528                     NaN                     NaN   NaN
#
#                                              Directions  CheckLists  \
# 662                        RETURN BIN AFTER COLLECTION.         NaN
# 663                                                 NaN         NaN
# 664                                                 NaN         NaN
# 665                                                 NaN         NaN
# 666   Rear lift bin with pockets  done by Remondis P...         NaN
# ...                                                 ...         ...
# 8986  AFTER 6AM bins located behind the shop in Bota...         NaN
# 8987  Bins on kerb next to roller door  entry via Da...         NaN
# 9068         Enter in via Alfreda Street  bins are out.         NaN
# 9381                    Done by Remondis at Taren point         NaN
# 9528     ** AFTER 7AM **  Shop 12  Penrith Trade Centre         NaN
#
#            Waste Type  Tip Site   Price   PO weekday
# 662          Organics       NaN   41.80  NaN       2
# 663          Organics       NaN   24.83  NaN       2
# 664         Cardboard       NaN   17.50  NaN       2
# 665          Comingle       NaN   20.75  NaN       2
# 666     General Waste       NaN  174.42  NaN       2
# ...               ...       ...     ...  ...     ...
# 8986        Cardboard       NaN   11.00  NaN       3
# 8987         Organics       NaN   13.20  NaN       3
# 9068       Food Waste       NaN   19.80  NaN       3
# 9381         Comingle       NaN   21.31  NaN       3
# 9528  Paper/Cardboard       NaN    9.41  NaN       3
#
# [137 rows x 42 columns]
